# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
"""
2. jointplot   sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')
3. pairplot    sns.pairplot(df)
4. boxplot     sns.boxplot(y='day',x='total_bill',hue='sex',data=df,palette='rainbow')
5. countplot   sns.countplot(df.sex)
6. voilionplot sns.violinplot(y=df.total_bill,x=df.smoker) # combo of kde and boxplot
7. heatmap     sns.heatmap(df.corr())
8. barplot     sns.barplot(df.day,df.tip,data=df,hue='sex') # x,y axis
"""

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.distplot(df.tip)

# %%
sns.distplot(df.tip,kde=False,bins=10) #kde is kernel density function

# %%
sns.countplot(df.sex)

# %%
sns.countplot(y=df.day)

# %%
sns.barplot(df.day,df.tip,data=df,hue='sex') # x,y axis

# %%
sns.boxplot(y='day',x='total_bill',hue='sex',data=df,palette='rainbow')

# %%
sns.boxplot(data=df,orient='v') # boxplotsforall categorical vars

# %%
sns.violinplot(y=df.total_bill,x=df.smoker) # combo of kde and boxplot
